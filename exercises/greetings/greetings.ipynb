# %% [markdown]
# # Greeting Exercise
#
# ## References
#
# - [Accessing Command Line Arguments in Python](https://github.com/christopheragonzales/python_morsels/blob/085a290c9fda01c35a61adff3bcb27e52e0f391d/Information/command_line/accessing_command_line_arguments_in_python.md)
# - [String Concatenation vs String Interpolation in Python](https://github.com/christopheragonzales/python_morsels/blob/02eb121d2fe9b4d238630c9c8444628fd74b2ab9/Information/strings/string_concatenation_vs_string_interpolation_in_python.md)
# - [Python's "If" Statement](https://github.com/christopheragonzales/python_morsels/blob/0fcca70f19b031dddf46334f649b7e643021e32f/Information/Conditionals/pythons_if_statement.md)
# - [Python's try-except Block](https://github.com/christopheragonzales/python_morsels/blob/085a290c9fda01c35a61adff3bcb27e52e0f391d/Information/Exceptions/pythons_try_except_blocks.md)
# - [Parsing Command Line Arguments](https://github.com/christopheragonzales/python_morsels/blob/features/cgonzales/20260405/greeting_exercise/Information/command_line/parsing_command_line_arguments_in_python.md)
